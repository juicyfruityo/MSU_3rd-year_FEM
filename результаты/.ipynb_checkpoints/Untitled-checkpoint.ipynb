# 4    5.0    6.0    7.0   25.0   24.0
# 5    6.0    7.0    8.0   26.0   25.0
# 6    7.0    8.0    2.0   10.0   26.0
# 7    8.0   20.0   21.0   27.0   19.0
# 8    9.0   21.0   22.0   28.0   27.0
# 9   10.0   22.0   23.0   29.0   28.0
# 10  11.0   23.0   24.0   30.0   29.0
# 11  12.0   24.0   25.0   31.0   30.0
# 12  13.0   25.0   26.0   32.0   31.0
# 13  14.0   26.0   10.0   11.0   32.0
# 14  15.0   19.0   27.0   18.0   12.0
# 15  16.0   27.0   28.0   17.0   18.0
# 16  17.0   28.0   29.0   16.0   17.0
# 17  18.0   29.0   30.0   15.0   16.0
# 18  19.0   30.0   31.0   14.0   15.0
# 19  20.0   31.0   32.0   13.0   14.0
# 20  21.0   32.0   11.0    9.0   13.0

# %%
df_nodes = pd.read_csv("nodes_df_6x3.txt", names=['ind', 'x', 'y'])

# %%
df_nodes
# Out:
#      ind         x    y
# 0    1.0  3.000000  1.5
# 1    3.0  2.142860  1.5
# 2   21.0  2.142860  0.5
# 3   20.0  3.000000  0.5
# 4    4.0  1.285710  1.5
# 5   22.0  1.285710  0.5
# 6    5.0  0.428571  1.5
# 7   23.0  0.428571  0.5
# 8    6.0 -0.428571  1.5
# 9   24.0 -0.428571  0.5
# 10   7.0 -1.285710  1.5
# 11  25.0 -1.285710  0.5
# 12   8.0 -2.142860  1.5
# 13  26.0 -2.142860  0.5
# 14   2.0 -3.000000  1.5
# 15  10.0 -3.000000  0.5
# 16  27.0  2.142860 -0.5
# 17  19.0  3.000000 -0.5
# 18  28.0  1.285710 -0.5
# 19  29.0  0.428571 -0.5
# 20  30.0 -0.428571 -0.5
# 21  31.0 -1.285710 -0.5
# 22  32.0 -2.142860 -0.5
# 23  11.0 -3.000000 -0.5
# 24  18.0  2.142860 -1.5
# 25  12.0  3.000000 -1.5
# 26  17.0  1.285710 -1.5
# 27  16.0  0.428571 -1.5
# 28  15.0 -0.428571 -1.5
# 29  14.0 -1.285710 -1.5
# 30  13.0 -2.142860 -1.5
# 31   9.0 -3.000000 -1.5

# %%
N = 50
x_grid = np.linspace(-0.2, 1.2, N)
y_grid = np.linspace(0, 1, N)

X_mesh, Y_mesh = np.meshgrid(x_grid, y_grid)

mesh = np.dstack((X_mesh, Y_mesh)).reshape(N*N, 2)
predictions = np.argmax(network.forward(mesh), 1)

plt.scatter(mesh[:, 0], mesh[:, 1], c=predictions, alpha=0.2)
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.axis('equal')
plt.show()

# %%
N = 50
x_grid = np.linspace(-3, 3, 8)
y_grid = np.linspace(-1.5, 1.5, 4)

X_mesh, Y_mesh = np.meshgrid(x_grid, y_grid)

# %%
mesh = np.dstack((X_mesh, Y_mesh)).reshape(32, 2)

# %%
N = 50
gridX = np.linspace(-3, 3, 40)
gridY = np.linspace(-1.5, 1.5, 20)

meshX, meshY = np.meshgrid(gridX, gridY)

meshXY = np.dstack((meshX, meshY)).reshape(800, 2)

# %%
df.loc[2*(df_nodes.ind-1), 2:]
# Out:
#           2             3             4             5             6   \
# 0.0   0.0000  0.000000e+00  0.000000e+00  0.000000e+00  3.688830e-21
# 4.0   0.0000  0.000000e+00  0.000000e+00  1.200840e-16  9.606600e-16
# 40.0  0.0000  0.000000e+00  0.000000e+00  2.516030e-17  2.012800e-16
# 38.0  0.0000  0.000000e+00  0.000000e+00  0.000000e+00
# 56.0 -1.962540e-05
# 58.0  1.404410e-05
# 60.0  5.338060e-05
# 62.0  1.975950e-05
# 20.0  5.864290e-08
# 34.0  3.867820e-12
# 22.0  2.143650e-15
# 32.0  5.146890e-09
# 30.0 -3.026490e-08
# 28.0 -3.057020e-08
# 26.0  4.026990e-08
# 24.0  4.062150e-08
# 16.0  1.038880e-08
#
# [32 rows x 27 columns]

# %%
# Out:
# 0

# %%
plt.scatter(df_nodes.x, df_nodes.y, alpha=0.2)
plt.scatter(meshXY[:, 0], meshXY[:, 1], alpha=0.2)
plt.axis('equal')
plt.show()

# %%
df.loc[2*(1-1), 2]
# Out:
# 0.0

# %%
[df_nodes[df_nodes.ind == 21].x.values[0], df_nodes[df_nodes.ind == 3].x.values[0]]
# Out:
# [2.1428599999999998, 2.1428599999999998]

# %%
test = np.array(df_nodes[df_nodes.id == 1].x[0], df_nodes[df_nodes.id == 1].y[0],
                 df.loc[2*(1-1), 2], df.loc[2*(1-1)+1, 2])

# %%
test_x = np.array([df_nodes[df_nodes.ind == 1].x.values[0], df_nodes[df_nodes.ind == 3].x.values[0],
                   df_nodes[df_nodes.ind == 21].x.values[0], df_nodes[df_nodes.ind == 20].x.values[0]])

test_x = np.array([df_nodes[df_nodes.ind == 1].y.values[0], df_nodes[df_nodes.ind == 3].y.values[0],
                   df_nodes[df_nodes.ind == 21].y.values[0], df_nodes[df_nodes.ind == 20].y.values[0]])

test_v = np.array([np.sqrt(df.loc[2*(1-1), 2]**2 + df.loc[2*(1-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(3-1), 2]**2 + df.loc[2*(3-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(21-1), 2]**2 + df.loc[2*(21-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(20-1), 2]**2 + df.loc[2*(20-1)+1, 2]**2)])

# %%
test_v = np.array([np.sqrt(df1000.loc[2*(6-1), 2]**2 + df1000.loc[2*(6-1)+1, 2]**2),
                   np.sqrt(df1000.loc[2*(7-1), 2]**2 + df1000.loc[2*(7-1)+1, 2]**2),
                   np.sqrt(df1000.loc[2*(25-1), 2]**2 + df1000.loc[2*(25-1)+1, 2]**2),
                   np.sqrt(df1000.loc[2*(24-1), 2]**2 + df1000.loc[2*(24-1)+1, 2]**2)])

# %%
test_v
# Out:
# array([0.35355339, 0.35355056, 0.17677528, 0.1767767 ])

# %%
def interpolate_test1(xi, eta):
    N1 = (1-xi) * (1-eta) / 4.0
    N2 = (1+xi) * (1-eta) / 4.0
    N3 = (1+xi) * (1+eta) / 4.0
    N4 = (1-xi) * (1+eta) / 4.0
    
    res = N1 * test_v[0] + N2 * test_v[1] \
        + N3 * test_v[2] + N4 * test_v[3]
    return res

# %%
interpolate_test1(0, 0)
# Out:
# 0.013258252147247768

# %%
df_nodes[df_nodes.ind == 7].x.values[0], df_nodes[df_nodes.ind == 8].x.values[0], df_nodes[df_nodes.ind == 6].y.values[0], df_nodes[df_nodes.ind == 23].y.values[0]
# Out:
# (-1.2857100000000001, -2.1428599999999998, 1.5, 0.5)

# %%
x_grid = np.linspace(df_nodes[df_nodes.ind == 5].x.values[0], df_nodes[df_nodes.ind == 6].x.values[0], 2)
y_grid = np.linspace(df_nodes[df_nodes.ind == 5].y.values[0], df_nodes[df_nodes.ind == 23].y.values[0], 2)

# %%
gridX = np.linspace(-0.428571, -1.2857100000000001, 100)
gridY = np.linspace(0.5, 1.5, 100)

meshX, meshY = np.meshgrid(gridX, gridY)

predX = np.linspace(-1,1,100)
predY = np.linspace(-1,1,100)
predX, predY = np.meshgrid(predX, predY)

# %%
meshXY = np.dstack((meshX, meshY)).reshape(10000, 2)

predXY = np.dstack((predX, predY)).reshape(10000, 2)
predict = interpolate_test1(predXY[:, 0], predXY[:, 1])

# %%
test_v[3]
# Out:
# 0.01767766952966369

# %%
test_v2[2]
# Out:
# 0.01767766952966369

# %%
test_v2 = np.array([np.sqrt(df.loc[2*(5-1), 2]**2 + df.loc[2*(5-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(6-1), 2]**2 + df.loc[2*(6-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(24-1), 2]**2 + df.loc[2*(24-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(23-1), 2]**2 + df.loc[2*(23-1)+1, 2]**2)])

def interpolate_test2(xi, eta):
    N1 = (1-xi) * (1-eta) / 4.0
    N2 = (1+xi) * (1-eta) / 4.0
    N3 = (1+xi) * (1+eta) / 4.0
    N4 = (1-xi) * (1+eta) / 4.0
    
    res = N1 * test_v2[0] + N2 * test_v2[1] \
        + N3 * test_v2[2] + N4 * test_v2[3]
    return res

gridX = np.linspace(0.428571,-0.428571, 100)
gridY = np.linspace(0.5, 1.5, 100)

meshX, meshY = np.meshgrid(gridX, gridY)

meshXY2 = np.dstack((meshX, meshY)).reshape(10000, 2)

predX = np.linspace(-1,1,100)
predY = np.linspace(-1,1,100)
predX, predY = np.meshgrid(predY, predX)
predXY = np.dstack((predX, predY)).reshape(10000, 2)
predict2 = interpolate_test2(predXY[:, 0], predXY[:, 1])

# %%
test_v2 = np.array([np.sqrt(df.loc[2*(7-1), 2]**2 + df.loc[2*(7-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(8-1), 2]**2 + df.loc[2*(8-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(26-1), 2]**2 + df.loc[2*(26-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(25-1), 2]**2 + df.loc[2*(25-1)+1, 2]**2)])

def interpolate_test3(xi, eta):
    N1 = (1-xi) * (1-eta) / 4.0
    N2 = (1+xi) * (1-eta) / 4.0
    N3 = (1+xi) * (1+eta) / 4.0
    N4 = (1-xi) * (1+eta) / 4.0
    
    res = N1 * test_v2[0] + N2 * test_v2[1] \
        + N3 * test_v2[2] + N4 * test_v2[3]
    return res

gridX = np.linspace(-1.2857100000000001,-2.1428599999999998, 100)
gridY = np.linspace(0.5, 1.5, 100)

meshX, meshY = np.meshgrid(gridX, gridY)

meshXY3 = np.dstack((meshX, meshY)).reshape(10000, 2)

predX = np.linspace(-1,1,100)
predY = np.linspace(-1,1,100)
predX, predY = np.meshgrid(predY, predX)
predXY = np.dstack((predX, predY)).reshape(10000, 2)
predict3 = interpolate_test2(predXY[:, 0], predXY[:, 1])

# %%
pred = np.concatenate((predict, predict2, predict3), axis=0)#([predict, predict2]

# %%
pred.shape
# Out:
# (20000,)

# %%
interpolate_test1(0, -1), interpolate_test2(1, -1)
# Out:
# (0.03535519763797114, 0.03535533905932738)

# %%
predict2[9]
# Out:
# 0.03535533905932738

# %%
mesh = np.concatenate((meshXY, meshXY2, meshXY3), axis=0)

# %%
plt.figure(figsize=(14,5))
plt.scatter(mesh[:, 0], mesh[:, 1], c=pred, alpha=0.2)
# plt.scatter(meshXY[:, 0], meshXY[:, 1], c=pred[:10000], alpha=0.2)
plt.axis('equal')
plt.xlim(0.5, -2.5)
plt.show()

# %%
df_elem
# Out:
#       id  node1  node2  node3  node4
# 0    1.0    1.0    3.0   21.0   20.0
# 1    2.0    3.0    4.0   22.0   21.0
# 2    3.0    4.0    5.0   23.0   22.0
# 3    4.0    5.0    6.0   24.0   23.0
# 4    5.0    6.0    7.0   25.0   24.0
# 5    6.0    7.0    8.0   26.0   25.0
# 6    7.0    8.0    2.0   10.0   26.0
# 7    8.0   20.0   21.0   27.0   19.0
# 8    9.0   21.0   22.0   28.0   27.0
# 9   10.0   22.0   23.0   29.0   28.0
# 10  11.0   23.0   24.0   30.0   29.0
# 11  12.0   24.0   25.0   31.0   30.0
# 12  13.0   25.0   26.0   32.0   31.0
# 13  14.0   26.0   10.0   11.0   32.0
# 14  15.0   19.0   27.0   18.0   12.0
# 15  16.0   27.0   28.0   17.0   18.0
# 16  17.0   28.0   29.0   16.0   17.0
# 17  18.0   29.0   30.0   15.0   16.0
# 18  19.0   30.0   31.0   14.0   15.0
# 19  20.0   31.0   32.0   13.0   14.0
# 20  21.0   32.0   11.0    9.0   13.0

# %%
for index in  df_elem.id:
    print(df_elem[df_elem.id == index].node1.values[0])
# Out:
# 1.0
# 3.0
# 4.0
# 5.0
# 6.0
# 7.0
# 8.0
# 20.0
# 21.0
# 22.0
# 23.0
# 24.0
# 25.0
# 26.0
# 19.0
# 27.0
# 28.0
# 29.0
# 30.0
# 31.0
# 32.0

# %%
del mesh
del pred

# %%
node1 = df_elem[df_elem.id == 5].node1.values[0]
node2 = df_elem[df_elem.id == 5].node2.values[0]
node3 = df_elem[df_elem.id == 5].node3.values[0]
node4 = df_elem[df_elem.id == 5].node4.values[0]

x1 = df_nodes[df_nodes.ind == node1].x.values[0]
x2 = df_nodes[df_nodes.ind == node2].x.values[0]
y1 = df_nodes[df_nodes.ind == node1].y.values[0]
y2 = df_nodes[df_nodes.ind == node4].y.values[0]

test_v = np.array([np.sqrt(df.loc[2*(node1-1), 2]**2 + df.loc[2*(node1-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(node2-1), 2]**2 + df.loc[2*(node2-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(node3-1), 2]**2 + df.loc[2*(node3-1)+1, 2]**2),
                   np.sqrt(df.loc[2*(node4-1), 2]**2 + df.loc[2*(node4-1)+1, 2]**2)])

def interpolate_test(xi, eta):
    N1 = (1-xi) * (1-eta) / 4.0
    N2 = (1+xi) * (1-eta) / 4.0
    N3 = (1+xi) * (1+eta) / 4.0
    N4 = (1-xi) * (1+eta) / 4.0

    res = N1 * test_v[0] + N2 * test_v[1] \
        + N3 * test_v[2] + N4 * test_v[3]
    return res

gridX = np.linspace(x1, x2, 100)
gridY = np.linspace(y2, y1, 100)

meshX, meshY = np.meshgrid(gridX, gridY)

meshXY = np.dstack((meshX, meshY)).reshape(10000, 2)

predX = np.linspace(1,-1,100)
predY = np.linspace(1,-1,100)
predX, predY = np.meshgrid(predY, predX)
predXY = np.dstack((predX, predY)).reshape(10000, 2)
predict = interpolate_test(predXY[:, 0], predXY[:, 1])

try:
    pred = np.concatenate((pred, predict), axis=0)
    mesh = np.concatenate((mesh, meshXY), axis=0)
except:
    pred = np.array(predict)
    mesh = np.array(meshXY)

# %%
test_v[0]
# Out:
# 0.03535533905932738

# %%
interpolate_test(1, -1)
# Out:
# 0.0353550562166149

# %%
plt.figure(figsize=(14,6))
plt.scatter(mesh[:, 0], mesh[:, 1], c=pred, alpha=0.2)
# plt.scatter(meshXY[:, 0], meshXY[:, 1], c=pred[:10000], alpha=0.2)
plt.axis('equal')
plt.xlim(-0.4, -1.5)
plt.show()

# %%
del mesh
del pred

# %%
# работает правильно!!!
#
for index in  df_elem.id:
    
    node1 = df_elem[df_elem.id == index].node1.values[0]
    node2 = df_elem[df_elem.id == index].node2.values[0]
    node3 = df_elem[df_elem.id == index].node3.values[0]
    node4 = df_elem[df_elem.id == index].node4.values[0]
    
    x1 = df_nodes[df_nodes.ind == node1].x.values[0]
    x2 = df_nodes[df_nodes.ind == node2].x.values[0]
    y1 = df_nodes[df_nodes.ind == node1].y.values[0]
    y2 = df_nodes[df_nodes.ind == node4].y.values[0]
    
    test_v = np.array([np.sqrt(df.loc[2*(node1-1), 2]**2 + df.loc[2*(node1-1)+1, 2]**2),
                       np.sqrt(df.loc[2*(node2-1), 2]**2 + df.loc[2*(node2-1)+1, 2]**2),
                       np.sqrt(df.loc[2*(node3-1), 2]**2 + df.loc[2*(node3-1)+1, 2]**2),
                       np.sqrt(df.loc[2*(node4-1), 2]**2 + df.loc[2*(node4-1)+1, 2]**2)])

    def interpolate_test(xi, eta):
        N1 = (1-xi) * (1-eta) / 4.0
        N2 = (1+xi) * (1-eta) / 4.0
        N3 = (1+xi) * (1+eta) / 4.0
        N4 = (1-xi) * (1+eta) / 4.0

        res = N1 * test_v[0] + N2 * test_v[1] \
            + N3 * test_v[2] + N4 * test_v[3]
        return res

    gridX = np.linspace(x2, x1, 100)
    gridY = np.linspace(y2, y1, 100)

    meshX, meshY = np.meshgrid(gridX, gridY)

    meshXY = np.dstack((meshX, meshY)).reshape(10000, 2)

    predX = np.linspace(1,-1,100)
    predY = np.linspace(1,-1,100)
    predX, predY = np.meshgrid(predY, predX)
    predXY = np.dstack((predX, predY)).reshape(10000, 2)
    predict = interpolate_test(predXY[:, 0], predXY[:, 1])
    
    try:
        pred = np.concatenate((pred, predict), axis=0)
        mesh = np.concatenate((mesh, meshXY), axis=0)
    except:
        pred = np.array(predict)
        mesh = np.array(meshXY)

# %%
plt.figure(figsize=(14,6))
plt.scatter(mesh[:, 0], mesh[:, 1], c=pred, alpha=0.2)
# plt.scatter(meshXY[:, 0], meshXY[:, 1], c=pred[:10000], alpha=0.2)
plt.axis('equal')
plt.xlim(2.5, -2.5)
plt.show()

# %%
def print_one(num):
#     del mesh
#     del pred
    
    for index in  df_elem.id:

        node1 = df_elem[df_elem.id == index].node1.values[0]
        node2 = df_elem[df_elem.id == index].node2.values[0]
        node3 = df_elem[df_elem.id == index].node3.values[0]
        node4 = df_elem[df_elem.id == index].node4.values[0]

        x1 = df_nodes[df_nodes.ind == node1].x.values[0]
        x2 = df_nodes[df_nodes.ind == node2].x.values[0]
        y1 = df_nodes[df_nodes.ind == node1].y.values[0]
        y2 = df_nodes[df_nodes.ind == node4].y.values[0]

        test_v = np.array([np.sqrt(df1000.loc[2*(node1-1), num]**2 + df1000.loc[2*(node1-1)+1, num]**2),
                           np.sqrt(df1000.loc[2*(node2-1), num]**2 + df1000.loc[2*(node2-1)+1, num]**2),
                           np.sqrt(df1000.loc[2*(node3-1), num]**2 + df1000.loc[2*(node3-1)+1, num]**2),
                           np.sqrt(df1000.loc[2*(node4-1), num]**2 + df1000.loc[2*(node4-1)+1, num]**2)])

        def interpolate_test(xi, eta):
            N1 = (1-xi) * (1-eta) / 4.0
            N2 = (1+xi) * (1-eta) / 4.0
            N3 = (1+xi) * (1+eta) / 4.0
            N4 = (1-xi) * (1+eta) / 4.0

            res = N1 * test_v[0] + N2 * test_v[1] \
                + N3 * test_v[2] + N4 * test_v[3]
            return res

        gridX = np.linspace(x2, x1, 100)
        gridY = np.linspace(y2, y1, 100)

        meshX, meshY = np.meshgrid(gridX, gridY)

        meshXY = np.dstack((meshX, meshY)).reshape(10000, 2)

        predX = np.linspace(1,-1,100)
        predY = np.linspace(1,-1,100)
        predX, predY = np.meshgrid(predY, predX)
        predXY = np.dstack((predX, predY)).reshape(10000, 2)
        predict = interpolate_test(predXY[:, 0], predXY[:, 1])

        try:
            pred = np.concatenate((pred, predict), axis=0)
            mesh = np.concatenate((mesh, meshXY), axis=0)
        except:
            pred = np.array(predict)
            mesh = np.array(meshXY)

    plt.figure(figsize=(14,6))
    plt.scatter(mesh[:, 0], mesh[:, 1], c=pred, alpha=0.2)
    # plt.scatter(meshXY[:, 0], meshXY[:, 1], c=pred[:10000], alpha=0.2)
    plt.axis('equal')
    plt.xlim(2.5, -2.5)
    plt.show()
    
    im = plt.scatter(mesh[:, 0], mesh[:, 1], c=pred, alpha=0.2)
    return im

# %%
nums = [2, 16, 25]
ims = []
for i in nums:
    ims.append(print_one(i))

# %%
import matplotlib.animation as animation

fig = plt.figure()

ani = animation.ArtistAnimation(fig, ims, interval=3, blit=True,
                                repeat_delay=1000)
# Out:
# Traceback (most recent call last):
#   File "/home/Albert/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "/home/Albert/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "/home/Albert/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py", line 1026, in _start
#     self._init_draw()
#   File "/home/Albert/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py", line 1556, in _init_draw
#     for artist in f:
# TypeError: 'PathCollection' object is not iterable

# %%
plt.show()

# %%
from matplotlib.animation import FuncAnimation

# %%
fig = plt.figure(figsize=(14,6))
anim = FuncAnimation(fig ,print_one, frames=[2, 8, 12, 16, 20, 25, 30], interval=300)
